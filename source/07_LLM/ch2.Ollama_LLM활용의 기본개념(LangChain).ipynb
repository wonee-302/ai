# %%
from IPython.display import display, HTML
display(HTML("""
<style>
div.container{width:95% !important;}
div.cell.code_cell.rendered{width:95%;}
div.input_prompt{padding:0px;}
div.CodeMirror {font-family:Consolas; font-size:22pt;}
.inner_cell{font-size:22pt;}
div.text_cell_render pre code {font-size:22pt; line-height:30px;}
div.output {font-size:20pt; font-weight:bold;}
div.input {font-family:Consolas; font-size:22pt;}
div.prompt {min-width:70px;}
div#toc-wrapper{padding-top:120px;}
div.text_cell_render li{font-size:20pt;padding:5px; line-height:30px;}
table.dataframe{font-size:22px;}
table td, th{font-size:16px;}
table{ margin-left:0 !important;   /* 왼쪽 여백 0 */}
</style>
"""))
# Out:
# <style>
# div.container{width:95% !important;}
# div.cell.code_cell.rendered{width:95%;}
# div.input_prompt{padding:0px;}
# div.CodeMirror {font-family:Consolas; font-size:22pt;}
# .inner_cell{font-size:22pt;}
# div.text_cell_render pre code {font-size:22pt; line-height:30px;}
# div.output {font-size:20pt; font-weight:bold;}
# div.input {font-family:Consolas; font-size:22pt;}
# div.prompt {min-width:70px;}
# div#toc-wrapper{padding-top:120px;}
# div.text_cell_render li{font-size:20pt;padding:5px; line-height:30px;}
# table.dataframe{font-size:22px;}
# table td, th{font-size:16px;}
# table{ margin-left:0 !important;   /* 왼쪽 여백 0 */}
# </style>

# %% [markdown]
# **<font size="6" color="red">ch2. Ollama_LLM활용의 기본 개념(LangChain)</font>**
#
# # 1.  LLM 을 활용하여 답변 생성
# ## 1) Ollama 이용한 로컬 LLM 이용
# - 성능은 GPT(open ai API), Claude같은 모델보다 떨어지나, 개념 설명을 위해 open source 모델 사용
#
# ### ollama.com 설치 -> 모델 pull
# - cmd창에서 ollama pull deepseek-r1:1.5b

# %%
from langchain_ollama import ChatOllama
llm = ChatOllama(model='deepseek-r1:1.5b')
result = llm.invoke('What is the capital of France?')
result # AIMessage
# content : 실제 답변
# response_metadata : 모델 실행에 대한 상세 정보(전체소요시간, 모델로딩시간, 처리토큰수)
# Out:
# AIMessage(content='\n\nThe capital of France is Paris.', additional_kwargs={}, response_metadata={'model': 'deepseek-r1:1.5b', 'created_at': '2026-09-10T07:55:53.5125732Z', 'done': True, 'done_reason': 'stop', 'total_duration': 2211284700, 'load_duration': 2077546100, 'prompt_eval_count': 10, 'prompt_eval_duration': 60644000, 'eval_count': 12, 'eval_duration': 67958000, 'logprobs': None, 'model_name': 'deepseek-r1:1.5b', 'model_provider': 'ollama'}, id='lc_run--01a08a50-e083-70a2-92f0-fce3653ca771-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 10, 'output_tokens': 12, 'total_tokens': 22})

# %%
print(result.content)
# Out:
# The capital of France is Paris.

# %% [markdown]
# ### 모델 pull
# - ollama pull llama3.2:1b
# - ollama 모델은 공식적으로 한글지원 안 됨(llama3.1:405b 한글지원 가능 -> llama3.2:3b한글 지원이 일부)
# - exaone 모델은 공식적으로 한글지원 : ollama pull exaone3.5:2.4b
#
# - 모델 저장 경로 : C:\Users\내컴퓨터이름\.ollama

# %%
from langchain_ollama import ChatOllama
llm = ChatOllama(model='llama3.2:1b', 
                temperature=0,        # 결정적인 출력
                num_predict=512,      # 최대 512 토큰까지 생성
                num_ctx=4096,          # 컨텍스트 윈도우 넉넉하게
                top_k=40,
                top_p=0.9,
                stop=["\n\n"])          # 두 줄바꿈 나오면 생성 중단)
result = llm.invoke('What is the capital of Korea?')
result
# Out:
# AIMessage(content='The capital of Korea is Seoul.', additional_kwargs={}, response_metadata={'model': 'llama3.2:1b', 'created_at': '2026-09-11T00:44:37.4830181Z', 'done': True, 'done_reason': 'stop', 'total_duration': 3878795500, 'load_duration': 3799757600, 'prompt_eval_count': 32, 'prompt_eval_duration': 39349000, 'eval_count': 8, 'eval_duration': 36955000, 'logprobs': None, 'model_name': 'llama3.2:1b', 'model_provider': 'ollama'}, id='lc_run--01a08dec-5fc3-7c21-8405-86195a36368c-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 32, 'output_tokens': 8, 'total_tokens': 40})

# %%
result.content
# Out:
# 'The capital of Korea is Seoul.'

# %%
llm = ChatOllama(model='exaone3.5:2.4b')
result = llm.invoke('한국 수도는 어디예요?')
result.content
# Out:
# '한국의 수도는 **서울**입니다. 이는 국제적으로 널리 알려진 사실이며, 정치 중심지이자 경제적 핵심 도시로 중요한 역할을 하고 있습니다.'

# %% [markdown]
# ## 2) openai 모델 활용
# - pip install langchain-openai

# %%
# 환경변수(`OPENAI_API_KEY` or `OPENAI_ADMIN_KEY` environment variable)
from dotenv import load_dotenv
import os
load_dotenv()
# print(os.getenv('OPENAI_API_KEY'))
# print(os.environ['OPENAI_API_KEY'])
# Out:
# True

# %%
from langchain_openai import ChatOpenAI
llm = ChatOpenAI(model="gpt-4.1-nano",
               # api_key=os.getenv('OPENAI_API_KEY')
                )
#result = llm.invoke('What is the capital of Korea?')
result = llm.invoke('한국의 수도가 어디예요?')
result.content
# Out:
# '한국의 수도는 서울입니다.'

# %%
result
# Out:
# AIMessage(content='한국의 수도는 서울입니다.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 7, 'prompt_tokens': 15, 'total_tokens': 22, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0, 'text_tokens': None}, 'prompt_tokens_details': {'audio_tokens': 0, 'cache_write_tokens': None, 'cached_tokens': 0, 'image_tokens': None, 'text_tokens': None}}, 'model_provider': 'openai', 'model_name': 'gpt-4.1-nano-2025-04-14', 'system_fingerprint': 'fp_bd3724d5d2', 'id': 'chatcmpl-EMknlX3kfPg8mzxUI95j15wkI5vJP', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--01a08e2e-db85-7032-a1b3-29a0a8dcac59-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 15, 'output_tokens': 7, 'total_tokens': 22, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}})

# %%
from langchain_anthropic import ChatAnthropic
llm = ChatAnthropic(model='claude-haiku-4-5-20251001')
# ANTHROPIC_API_KEY environment variable
# llm.invoke('What is the capital of Korea?')

# %% [markdown]
# # 2. 렝체인 스타일로 프롬프트 작성하기
# - 프롬프트 : llm호출시 쓰는 질문
#
# ## 1) 기본 프롬프트 템플릿 사용
# - PromptTemplate 을 사용하여 변수가 포함된 템플릿 작성하면 PromptValue를 만들 수 있다

# %%
from langchain_ollama import ChatOllama
llm = ChatOllama(model='llama3.2:1b')
# llm.invoke(0)
llm.invoke("What is the capital of Korea")
# 프롬프트 가능 타입 : str, PromptValue, list of BaseMessages
# Out:
# AIMessage(content='The capital of South Korea is Seoul.', additional_kwargs={}, response_metadata={'model': 'llama3.2:1b', 'created_at': '2026-09-11T03:02:18.1888952Z', 'done': True, 'done_reason': 'stop', 'total_duration': 2590781100, 'load_duration': 2509949400, 'prompt_eval_count': 31, 'prompt_eval_duration': 39923000, 'eval_count': 9, 'eval_duration': 37550000, 'logprobs': None, 'model_name': 'llama3.2:1b', 'model_provider': 'ollama'}, id='lc_run--01a08e6a-712d-7921-9396-973556dd2cae-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 31, 'output_tokens': 9, 'total_tokens': 40})

# %%
from langchain_core.prompts import PromptTemplate
prompt_template = PromptTemplate(
                template="What is the capital of {country}?", # {}안에 값을 새로운 값으로 대체
                input_variables = ['country']
        )
prompt = prompt_template.invoke({"country":"Korea"})
print(1, type(prompt))
prompt = prompt_template.invoke("Korea")
print(2, prompt)
llm.invoke(prompt)
# Out:
# 1 <class 'langchain_core.prompt_values.StringPromptValue'>
# 2 text='What is the capital of Korea?'
# AIMessage(content='The capital of Korea is Seoul.', additional_kwargs={}, response_metadata={'model': 'llama3.2:1b', 'created_at': '2026-09-11T03:02:18.2757258Z', 'done': True, 'done_reason': 'stop', 'total_duration': 63452400, 'load_duration': 2397100, 'prompt_eval_count': 32, 'prompt_eval_duration': 22873000, 'eval_count': 8, 'eval_duration': 34903000, 'logprobs': None, 'model_name': 'llama3.2:1b', 'model_provider': 'ollama'}, id='lc_run--01a08e6a-7b63-7e71-8c1d-0a1f7e3380a7-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 32, 'output_tokens': 8, 'total_tokens': 40})

# %%
country = input('수도를 알고 싶은 나라는(영어)?')
llm.invoke(prompt_template.invoke(country))
# Out:
# 수도를 알고 싶은 나라는(영어)?France
# AIMessage(content='The capital of France is Paris.', additional_kwargs={}, response_metadata={'model': 'llama3.2:1b', 'created_at': '2026-09-11T02:36:12.5450431Z', 'done': True, 'done_reason': 'stop', 'total_duration': 7945483000, 'load_duration': 1579900, 'prompt_eval_count': 32, 'prompt_eval_duration': 7905885000, 'eval_count': 8, 'eval_duration': 33579000, 'logprobs': None, 'model_name': 'llama3.2:1b', 'model_provider': 'ollama'}, id='lc_run--01a08e52-7876-79e2-8d90-9059d41a705e-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 32, 'output_tokens': 8, 'total_tokens': 40})

# %%
def answer(country):
    '나라명을 입력받아 llm에게 수도명을 받아 return'
    from langchain_ollama import ChatOllama
    from langchain_core.prompts import PromptTemplate
    llm = ChatOllama(model='llama3.2:1b')
    prompt_template = PromptTemplate(
                        template='What is the capital of {country}?',
                        input_variables = ['country']
                    )
    result = llm.invoke(prompt_template.invoke(country))
    return result.content

# %%
country = input("수도를 알고 싶은 나라는(영어)>")
answer(country)
# Out:
# 수도를 알고 싶은 나라는(영어)>Turkey
# 'The capital of Turkey is Ankara.'

# %% [markdown]
# ## 2) 메세지 기반 프롬프트 작성
# - list of BaseMessages
# - BaseMessage 상속받은 클래스 : AIMessage, HumanMessage, SystemMessage, ToolMessage
# - [BaseMessage객체, BaseMessage객체, BaseMessage객체, ...]

# %%
from langchain_core.messages import AIMessage, HumanMessage, SystemMessage
from langchain_ollama import ChatOllama
llm = ChatOllama(model='llama3.2:1b')
message_list = [
    SystemMessage(content="You are a helpful assistant!"), # llm 페로소나
    HumanMessage(content="What is the capital of Italy?"), # 질문 답변 예제(few shot)
    AIMessage(content='The capital of Italy is Rome.'),
    HumanMessage(content="What is the capital of France?"), # 질문 답변 예제(few shot)
    AIMessage(content='The capital of France is Paris.'),
    HumanMessage(content='What is the capital of Korea?') # llm에게 질문하고 싶은 진짜 내용
]
llm.invoke(message_list)
# Out:
# AIMessage(content='The capital of South Korea is Seoul. The capital of North Korea is Pyongyang.', additional_kwargs={}, response_metadata={'model': 'llama3.2:1b', 'created_at': '2026-09-11T03:18:36.5599959Z', 'done': True, 'done_reason': 'stop', 'total_duration': 138549000, 'load_duration': 1576500, 'prompt_eval_count': 86, 'prompt_eval_duration': 10133000, 'eval_count': 17, 'eval_duration': 124462000, 'logprobs': None, 'model_name': 'llama3.2:1b', 'model_provider': 'ollama'}, id='lc_run--01a08e79-6884-7d82-98da-29834f68377e-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 86, 'output_tokens': 17, 'total_tokens': 103})

# %% [markdown]
# ## 3) ChatPromptTemplate 사용(추천; 확장성 용이)
# - BaseMessage 리스트 -> 튜플리스트

# %%
from langchain_core.prompts import ChatPromptTemplate
chatPromptTemplate = ChatPromptTemplate([
    SystemMessage(content="You are a helpful assistant!"), # llm 페로소나
    HumanMessage(content="What is the capital of Italy?"), # 질문 답변 예제(few shot)
    AIMessage(content='The capital of Italy is Rome.'),
    HumanMessage(content="What is the capital of France?"), # 질문 답변 예제(few shot)
    AIMessage(content='The capital of France is Paris.'),
    HumanMessage(content='What is the capital of {country}?') # llm에게 질문하고 싶은 진짜 내용
])
prompt = chatPromptTemplate.invoke({'country':'Korea'})
print('프롬프트 :', prompt)
# Out:
# 프롬프트 : messages=[SystemMessage(content='You are a helpful assistant!', additional_kwargs={}, response_metadata={}), HumanMessage(content='What is the capital of Italy?', additional_kwargs={}, response_metadata={}), AIMessage(content='The capital of Italy is Rome.', additional_kwargs={}, response_metadata={}, tool_calls=[], invalid_tool_calls=[]), HumanMessage(content='What is the capital of France?', additional_kwargs={}, response_metadata={}), AIMessage(content='The capital of France is Paris.', additional_kwargs={}, response_metadata={}, tool_calls=[], invalid_tool_calls=[]), HumanMessage(content='What is the capital of {country}?', additional_kwargs={}, response_metadata={})]

# %%
from langchain_core.prompts import ChatPromptTemplate
chatPromptTemplate = ChatPromptTemplate([
    ("system", "You are a helpful assistant!"), # llm 페로소나    
    ("human", "What is the capital of Italy?"), # few shot
    ("ai", "The capital of Italy is Rome."),
    ("human", "What is the capital of France?"),
    ("ai", "The capital of France is Paris."),
    ("human", "What is the capital of {country}?")
])
prompt = chatPromptTemplate.invoke({'country':'Korea'})
print('프롬프트 :', prompt)
# Out:
# 프롬프트 : messages=[SystemMessage(content='You are a helpful assistant!', additional_kwargs={}, response_metadata={}), HumanMessage(content='What is the capital of Italy?', additional_kwargs={}, response_metadata={}), AIMessage(content='The capital of Italy is Rome.', additional_kwargs={}, response_metadata={}, tool_calls=[], invalid_tool_calls=[]), HumanMessage(content='What is the capital of France?', additional_kwargs={}, response_metadata={}), AIMessage(content='The capital of France is Paris.', additional_kwargs={}, response_metadata={}, tool_calls=[], invalid_tool_calls=[]), HumanMessage(content='What is the capital of Korea?', additional_kwargs={}, response_metadata={})]

# %%
# llm.invoke(chatPromptTemplate.invoke({'country':'Korea'}))
llm.invoke(chatPromptTemplate.invoke({'Korea'}))
# Out:
# AIMessage(content='The capital of Korea is Seoul.', additional_kwargs={}, response_metadata={'model': 'llama3.2:1b', 'created_at': '2026-09-11T03:51:45.1850294Z', 'done': True, 'done_reason': 'stop', 'total_duration': 365954500, 'load_duration': 1583800, 'prompt_eval_count': 89, 'prompt_eval_duration': 170840000, 'eval_count': 8, 'eval_duration': 190831000, 'logprobs': None, 'model_name': 'llama3.2:1b', 'model_provider': 'ollama'}, id='lc_run--01a08e97-bfb1-7bf1-9515-d8194847c1e8-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 89, 'output_tokens': 8, 'total_tokens': 97})

# %% [markdown]
# # 3. 답변 형식 컨트롤하기
# - invoke 실행 결과 AIMessage() -> String, json 변환해주는 OutputParser 이용
#
# ## 1) 문자열 출력 파서 이용
# - StrOutputParser를 이용하여 LLM출력(AIMessage)를 단순 문자열로 변환

# %%
from langchain_core.prompts import PromptTemplate
from langchain_core.output_parsers import StrOutputParser
# 명시적인 지시사항이 포함된 프롬프트
prompt_template = PromptTemplate(
    template='What is the capital of {country}? Return the name of the city only.',
    input_variables = ['country']
)
# 프롬프트 템플릿에 값 주입
prompt = prompt_template.invoke({'country':'Korea'})
print('프롬프트 :', prompt)
# llm에 질문
aimessage = llm.invoke(prompt)
# aimessage중 답변만 문자로 받기
output_parser = StrOutputParser()
result = output_parser.invoke(aimessage)
print('파서 결과 :',result)
# Out:
# 프롬프트 : text='What is the capital of Korea? Return the name of the city only.'
# 파서 결과 : Seoul

# %%
output_parser.invoke(llm.invoke(prompt_template.invoke({'country':'Korea'})))
output_parser.invoke(llm.invoke(prompt_template.invoke('Korea')))
# Out:
# 'Seoul'

# %%
chatPromptTemplate = ChatPromptTemplate([
    ("system", "You are a helpful assistant!"), # llm 페로소나    
    ("human", "What is the capital of Italy?"), # few shot
    ("ai", "The capital of Italy is Rome."),
    ("human", "What is the capital of France?"),
    ("ai", "The capital of France is Paris."),
    ("human", "What is the capital of {country}? Return the name of the city only.")
])
output_parser = StrOutputParser()
output_parser.invoke(llm.invoke(chatPromptTemplate.invoke({'country':'Korea'})))
# Out:
# 'Seoul'

# %% [markdown]
# ## 2) Json 출력파서 이용
# - {'name':'홍','age':20}

# %%
from langchain_ollama import ChatOllama
from langchain_core.prompts import PromptTemplate
from langchain_core.output_parsers import StrOutputParser, JsonOutputParser
llm = ChatOllama(model='llama3.2:1b')
country_detail_prompt = PromptTemplate(
    template="""Give following information about {country}.
        - Capital
        - Population
        - Language
        - Currency
    Return ONLY a valid JSON object with no additional text.
    Example format :
    {{"Capital":"Seoul", "Population":"50 million", "Language":"Korean", "Currency":"won"}}
    """,
    input_variables = ['country']
)
prompt = country_detail_prompt.invoke({'country':'France'})
aimessage = llm.invoke(prompt)
output_parser = JsonOutputParser()
result = output_parser.invoke(aimessage)
print(type(result), result)
# Out:
# <class 'dict'> {'Capital': 'Paris', 'Population': '67 million', 'Language': 'French', 'Currency': 'Euro'}

# %%
info = output_parser.invoke(llm.invoke(country_detail_prompt.invoke('France')))
info
# Out:
# {'Capital': 'Paris',
#  'Population': '67 million',
#  'Language': 'French',
#  'Currency': 'Euro'}

# %% [markdown]
# ## 3) 구조화된 객체로 반환
# - Pydantic 모델(pip show pydantic)을 사용하여 LLM출력을 구조화된 형식으로 받기(JsonParser 좀 안정적)
# - Pydantic : 데이터 유효성 검사, 설정관리를 간편하게 해주는 라이브러리

# %%
class User:
    def __init__(self, id, name, is_active=True):
        self.id = id
        self.name = name
        self.is_active = is_active
user = User('1', "홍길동")
user = User(1, "홍", "활성화됨")
print(user)
print(user.id, user.name, user.is_active)
# Out:
# <__main__.User object at 0x00000273F336FDC0>
# 1 홍 활성화됨

# %%
from pydantic import BaseModel, Field
class User(BaseModel):
    # gt=0 : id>0, lt=0 : id<0, ge=0 : id>=0, le=0: id<=0
    id:int         = Field(gt=0,         description='id')
    name:str       = Field(min_length=2, description='name')
    is_active:bool = Field(default=True, description='id활성화')
user = User(id="1", name='홍길동', is_active=True)
print(user)
# Out:
# id=1 name='홍길동' is_active=True

# %%
country_detail_prompt = PromptTemplate(
    template="""Give following information about {country}.
        - Capital
        - Population
        - Language
        - Currency
    Return ONLY a valid JSON object with no additional text.
    """,
    input_variables = ['country']
)
class CountryDetail(BaseModel):
    capital:str   = Field(description="the capital of the country")
    population:int= Field(description="the population of the country")
    language:str  = Field(description="the language of the country")
    currency:str  = Field(description="the currency of the country")
# 출력파서 + llm
structedllm = llm.with_structured_output(CountryDetail)
info = structedllm.invoke(country_detail_prompt.invoke({'country':'Korea'}))
print(type(info))
print(info)
print(info.capital, info.population, info.language, info.currency)
print(info.model_dump()) # 객체를 dict로
# Out:
# <class '__main__.CountryDetail'>
# capital='Seoul' population=51000000 language='Korean' currency='Korean won'
# Seoul 51000000 Korean Korean won
# {'capital': 'Seoul', 'population': 51000000, 'language': 'Korean', 'currency': 'Korean won'}

# %%
aimessage = llm.invoke(country_detail_prompt.invoke({'country':'Korea'}))
print(aimessage.content)
# Out:
# {
#   "capital": "Seoul",
#   "population": "51.8 million",
#   "language": "Korean",
#   "currency": "Korean won"

# %% [markdown]
# # 4. LCEL(LangChain Expression Language)을 활용한 렝체인 생성
# ## 1) 문자열 출력 파서 사용
# - StrOutputParser, ChatOllama, PromptTemplate등은 모두 Runable로 상속받아 invoke가 있음

# %%
from langchain_core.prompts import PromptTemplate
from langchain_core.output_parsers import StrOutputParser
# 명시적인 지시사항이 포함된 프롬프트
prompt_template = PromptTemplate(
    template='What is the capital of {country}? Return the name of the city only.',
    input_variables = ['country']
)
outputParser = StrOutputParser()
outputParser.invoke(llm.invoke(prompt_template.invoke({'country':'Korea'})))
# Out:
# 'Seoul'

# %% [markdown]
# ## 2) LCEL을 사용한 체인 구성
# - (|) 사용

# %%
# 프롬프트 템플릿 -> llm -> 출력파서를 연결시키는 체인 생성
capital_chain = prompt_template | llm | outputParser
# 생성된 체인 invoke
capital_chain.invoke({'country':'Korea'})
capital_chain.invoke('Korea')
# Out:
# 'Seoul'

# %%
type(capital_chain)
# Out:
# langchain_core.runnables.base.RunnableSequence

# %% [markdown]
# ## 3) 복합 체인 구성
# - 여러 단계의 추론이 필요한 경우 (체인 연결)

# %%
# 나라 설명 -> 나라이름
country_prompt = PromptTemplate(
                    template="""
                    Guess the name of the country based on the following information:
                    {information}
                    Return the name of the country only""",
                input_variables=['information']
)
outputParser.invoke(llm.invoke(country_prompt.invoke({'information':
                                            "This country is very famous for its wine"})))
# Out:
# 'Italy'

# %%
# 나라명 추측 체인
country_chain = country_prompt | llm | outputParser
country_chain.invoke({'information':'This country is very famous for its wine'})
# Out:
# 'France'

# %%
# 국가설명 (-> 국가명 ->) 그 국가 수도명
final_chain = country_chain | capital_chain
final_chain.invoke({'information':'This country is very famous for its wine'})
# Out:
# 'Madrid'

# %%
# 국가설명 -> 국가명 -> 그 국가 수도명
final_chain = {'country':country_chain} | capital_chain

final_chain.invoke({'information':'This country is very famous for its wine'})
# Out:
# 'Rome'

# %%
final_chain.invoke({'information':'와인으로 유명해요'})
# Out:
# 'Rome'

# %% [markdown]
# ```
# LLM호출 : ChatOllama(llama3.2:1b / exaone3.5:2.4b), ChatOpenAI
# LLM 호출에 필요한 프롬프트 템플릿 : PromptTemplate, ChatPromptTemplate(few shot, 페르소나설정)
# LLM 결과를 변환 outputParser : str/JSON/pydentic 클래스 생성하여 LLM의 Structed outputParser 이용
# 위 모두 runnable로부터 상속받은 invoke 가능 => LangChain으로 연결 가능 (=>RAG)
# ```
# # 5. 생성형 AI  평가 :
# - 첫번째 체인 : 나라이름 -> 그 나라에서 가장 유명한 음식
# - 두번째 체인 : 음식 -> 음식의 레시피
# - 최종 체인 : 나라이름 -> 그 나라에 가장 유명한 음식의 레시피
# - "{country}사람이 좋아하는 음식 레시피"하고 한번에 가도 되나, 체인을 쪼개는 습관이 좋음

# %% [markdown]
# ## 1) LLM 설정 (llama3.2:1b)
# - Temperature를 0으로 설정하면 LLM이 더 일관된 답변을 제공합니다.

# %%
from langchain_ollama import ChatOllama

# Temperature를 0으로 설정하여 일관된 답변 유도
llm = ChatOllama(
    model="llama3.2:1b",
    temperature=0,
)

# %% [markdown]
# ## 2) 음식 추천 체인 구성 (프롬프트 팁 2: 명확한 출력 형식 지정)
# - 프롬프트에서 원하는 출력 형식을 명확하게 지정하면 더 정확한 응답을 얻을 수 있습니다.

# %%
# 음식 이름 찾기

from langchain_core.output_parsers import StrOutputParser
from langchain_core.prompts import PromptTemplate

# 음식 이름만 반환하도록 명확하게 지시
food_prompt = PromptTemplate(
    template='''what is one of the most popular food in {country}? 
        Please return the name of the food only''', 
    input_variables=['country']
)

# 음식 추천 체인 구성
food_chain = food_prompt | llm | StrOutputParser()
# 음식 추천 체인 실행
food_chain.invoke({'country': 'South Korea'})
# Out:
# 'Bibimbap'

# %% [markdown]
# ## 3) 레시피 생성 체인 구성 (프롬프트 팁 3: 시스템 메시지 활용)
# - 시스템 메시지를 통해 LLM의 역할과 응답 형식을 명확하게 정의할 수 있습니다.

# %%
from langchain_core.prompts import ChatPromptTemplate

# 시스템 메시지를 통해 레시피 형식 지정
recipe_prompt = ChatPromptTemplate.from_messages([
    ('system', '''Provide the recipe of the food that the user wants. 
Please return the recipe only as a numbered list without any explanation'''), #input token보다 output token이 비쌈
    ('human', 'Can you give me the recipe for making {food}?')
])

# 레시피 생성 체인 구성
recipe_chain = recipe_prompt | llm | StrOutputParser()
# 레시피 생성 체인 실행
print(recipe_chain.invoke({'food': 'Bibimbap'}))
# Out:
# Here's a recipe for Bibimbap:
#
# 1. Cook the rice:
# 	* Rinse 2 cups of white or brown rice and cook according to package instructions.
# 	* Allow the rice to cool.
# 2. Prepare the vegetables:
# 	* Slice 1 cup of zucchini, 1 cup of carrots, and 1 cup of bean sprouts.
# 	* Slice 1/2 cup of cucumber and 1/4 cup of red bell pepper.
# 	* Grate 1/2 cup of daikon radish.
# 3. Prepare the meat (optional):
# 	* Slice 1/2 cup of beef (such as ribeye or sirloin) into thin strips.
# 	* Slice 1/2 cup of chicken breast into thin strips.
# 4. Prepare the sauce:
# 	* Whisk together 2 tablespoons of soy sauce, 1 tablespoon of rice vinegar, 1 tablespoon of Gochujang (Korean chili paste), and 1 tablespoon of sugar.
# 5. Assemble the Bibimbap:
# 	* Divide the cooked rice into a large bowl.
# 	* Arrange the vegetables, meat (if using), and sauce on top of the rice.
# 6. Serve and enjoy:
# 	* Garnish with toasted sesame seeds and chopped green onions.
# 	* Serve immediately and let everyone build their own Bibimbap.

# %% [markdown]
# ## 4) 체인 연결을 통한 최종 체인 구성
# - 여러 체인을 연결하여 복잡한 작업을 단계별로 처리할 수 있습니다.

# %%
# 음식 추천과 레시피 생성을 연결한 최종 체인 구성
from langchain_core.runnables import RunnablePassthrough
final_chain = food_chain | recipe_chain
# final_chain = {'food': food_chain} | recipe_chain

# %%
# 국가 입력으로 대표 음식을 찾고, 해당 음식의 레시피까지 자동으로 생성
recipe = final_chain.invoke("France")
print(recipe)
# Out:
# Here is a recipe for making croissants:
#
# 1. Make the dough:
# 	* 1 1/2 cups warm milk (105°F to 115°F)
# 	* 1/4 cup granulated sugar
# 	* 2 teaspoons active dry yeast
# 	* 3 1/2 cups all-purpose flour
# 	* 1 teaspoon salt
# 	* 1/4 cup unsalted butter, melted
# 	* 1 egg, beaten (for egg wash)
#
# 2. Proof the dough:
# 	* Let the dough rest for 1 hour, or until it has doubled in size.
#
# 3. Roll out the dough:
# 	* Roll out the dough to a thickness of 1/4 inch (6 mm).
#
# 4. Laminate the dough:
# 	* Fold the dough in half lengthwise, like a letter.
# 	* Rotate the dough 90°.
# 	* Roll out the dough to a thickness of 1/4 inch (6 mm).
#
# 5. Repeat the laminating process:
# 	* Fold the dough in half lengthwise, like a letter.
# 	* Rotate the dough 90°.
# 	* Roll out the dough to a thickness of 1/4 inch (6 mm).
#
# 6. Cut the croissants:
# 	* Cut the dough into long, thin triangles.
# 	* Cut each triangle in half, so that you have a total of 16 triangles.
#
# 7. Roll out the triangles:
# 	* Roll out each triangle into a long, thin rectangle.
#
# 8. Laminate the triangles:
# 	* Roll the rectangle into a tight log, starting from the wide end.
# 	* Cut the log into 4 equal pieces.
#
# 9. Roll out the croissants:
# 	* Roll out each piece of dough into a thin sheet, about 1/16 inch (1.5 mm) thick.
#
# 10. Cut the croissants:
# 	* Cut the dough into long, thin triangles.
# 	* Cut each triangle in half, so that you have a total of 32 triangles.
#
# 11. Laminate the croissants:
# 	* Roll out each triangle into a long, thin rectangle.
# 	* Roll the rectangle into a tight log, starting from the wide end.
# 	* Cut the log into 4 equal pieces.
#
# 12. Bake the croissants:
# 	* Place the croissants on a baking sheet lined with parchment paper.
# 	* Brush the tops with egg wash.
# 	* Bake in a preheated oven at 400°F (200°C) for 15-20 minutes, or until golden brown.
#
# Note: Making croissants requires a lot of time and effort, but the end result is well worth it. Be patient and don't be discouraged if your first batch doesn't turn out perfectly.

# %% [markdown]
# ## ※ 한국어 공식 지원 모델(exaone3.5:2.4b;deep은 추론 과정까지 설명함) 사용

# %%
# 음식 이름 찾기 (ollama 렝체인시 한국어를 사용하니 잘 안 됨. 하나하나는 됨)

from langchain_core.output_parsers import StrOutputParser
from langchain_core.prompts import PromptTemplate
from langchain_ollama import ChatOllama
from langchain_core.prompts import ChatPromptTemplate
llm = ChatOllama(
    model="exaone3.5:2.4b",
    temperature=0,
)
# 음식 이름만 반환하도록 명확하게 지시
food_prompt = PromptTemplate(
    template='''{country}에서 가장 인기 있는 음식 중 하나는 무엇인가요?
                음식 이름만 한단어로 반환해 주세요''',
    input_variables=['country']
)

# 음식 추천 체인 구성
food_chain = food_prompt | llm | StrOutputParser()
# 음식 추천 체인 실행
food_chain.invoke({'country': '한국'})
# Out:
# '비빔밥'

# %%
# 시스템 메시지를 통해 레시피 형식 지정
recipe_prompt = ChatPromptTemplate.from_messages([
    ('system', '사용자가 원하는 음식의 레시피를 제공합니다. 번호를 달아 설명해 주세요'), #input token보다 output token이 비쌈
    ('human', '{food}을 만드는 레시피를 알려주세요')
])

# 레시피 생성 체인 구성
recipe_chain = recipe_prompt | llm | StrOutputParser()
# 레시피 생성 체인 실행
recipe = recipe_chain.invoke({'food': '비빔밥'}) #input token보다 output token이 비쌈
print(recipe)
# Out:
# ## 맛있는 비빔밥 레시피 🍲✨
#
# **재료 (4인분 기준)**
#
# 1. **밥**
#     * 백미 2컵
#     * 물 2컵 (물의 양은 밥의 양에 따라 조절)
# 2. **기본 재료**
#     * **고기**
#         * 소고기 등심 100g (불고기감으로 사용 가능) - 얇게 썰어줍니다.
#         * 간장 1큰술, 설탕 1/2큰술, 참기름 약간, 다진 마늘 약간, 후추 약간을 섞어 양념합니다. 고기에 양념을 골고루 발라줍니다.
#         * 팬에 기름을 두르고 고기를 볶아줍니다. 익으면 불을 끄고 식혀줍니다.
#     * **야채**
#         * 시금치 200g - 살짝 데쳐서 소금으로 간을 합니다.
#         * 당근 1/2개 - 채 썰어 볶아줍니다.
#         * 오이 1/2개 - 채 썰어 볶아줍니다.
#         * 고사리 100g - 깨끗이 씻어 물에 불린 후 볶아줍니다.
#         * 콩나물 100g - 깨끗이 씻어 소금으로 간을 합니다.
#     * **기타**
#         * 계란 1개 - 삶아서 반으로 썰어줍니다.
#         * 김가루 약간
#         * 참기름 약간
#         * 깨 약간
#         * 고추장 또는 간장 기반의 비빔장 (선택 사항)
#
# 3. **장식**
#     * 파 다진 것 약간 (선택 사항)
#
# **만드는 방법**
#
# 1. **밥 짓기:** 백미를 씻어 물에 불린 후 밥솥에 넣고 밥을 지어줍니다.
# 2. **고기 볶기:** 팬에 기름을 두르고 볶은 고기를 준비합니다.
# 3. **야채 볶기:** 각 야채를 따로 볶아 준비합니다. 시금치는 데쳐서 소금으로 간을 합니다.
# 4. **계란 프라이:** 계란을 삶아 반으로 썰어 준비합니다.
# 5. **비빔밥 그릇에 담기:** 밥을 그릇에 담고, 준비한 고기, 야채, 계란을 골고루 얹습니다.
# 6. **마무리:** 김가루, 참기름, 깨를 뿌려줍니다.
# 7. **비빔장 추가:** 취향에 따라 비빔장을 넣고 잘 섞어줍니다.
# 8. **마지막 장식:** 파를 뿌려 완성합니다.
#
# **팁**
#
# * 다양한 야채를 활용하여 비빔밥의 맛과 영양을 더할 수 있습니다. (예: 오이고추, 버섯, 콩나물 대신 두부 등)
# * 고기 대신 두부, 버섯 등 채식주의자를 위한 재료도 사용 가능합니다.
# * 비빔장은 고추장, 간장, 설탕, 참기름 등을 섞어 직접 만들거나 시중에 판매하는 제품을 사용할 수 있습니다.
#
# 맛있게 드세요! 🥗✨

# %%
# 음식 추천과 레시피 생성을 연결한 최종 체인 구성
from langchain_core.runnables import RunnablePassthrough
final_chain = food_chain | recipe_chain
# final_chain = {'food': food_chain} | recipe_chain
# 국가 입력으로 대표 음식을 찾고, 해당 음식의 레시피까지 자동으로 생성
recipe = final_chain.invoke("한국")
print(recipe)
# Out:
# ## 맛있는 비빔밥 레시피 🍲✨
#
# **재료 (4인분 기준)**
#
# 1. **밥**
#     * 백미 2컵
#     * 물 2컵 (물의 양은 밥의 양에 따라 조절)
# 2. **기본 재료**
#     * **고기**
#         * 소고기 등심 100g (불고기감으로 사용 가능) - 얇게 썰어줍니다.
#         * 간장 1큰술, 설탕 1/2큰술, 참기름 약간, 다진 마늘 약간, 후추 약간을 섞어 양념합니다. 고기에 양념을 골고루 발라줍니다.
#         * 팬에 기름을 두르고 고기를 볶아줍니다. 익으면 불을 끄고 식혀줍니다.
#     * **야채**
#         * 시금치 200g - 살짝 데쳐서 소금으로 간을 합니다.
#         * 당근 1/2개 - 채 썰어 볶아줍니다.
#         * 오이 1/2개 - 채 썰어 볶아줍니다.
#         * 고사리 100g - 깨끗이 씻어 물에 불린 후 볶아줍니다.
#         * 콩나물 100g - 깨끗이 씻어 소금으로 간을 합니다.
#     * **기타**
#         * 계란 1개 - 삶아서 반으로 썰어줍니다.
#         * 김가루 약간
#         * 참기름 약간
#         * 깨 약간
#         * 고추장 또는 간장 기반의 비빔장 (선택 사항)
#
# **만드는 방법**
#
# 1. **밥 짓기:** 냄비에 백미와 물을 넣고 끓입니다. 끓으면 불을 끄고 15분간 뜸을 들여줍니다.
# 2. **고기 볶기:** 팬에 기름을 두르고 고기를 볶아 익힙니다. 식힌 후 잘게 다져줍니다.
# 3. **야채 볶기:** 각 야채를 따로 볶아줍니다. 시금치는 데쳐서 소금으로 간을 하고, 다른 야채들은 볶아서 준비합니다.
# 4. **비빔장 만들기:** 고추장에 간장, 설탕, 다진 마늘, 참기름을 넣고 섞어 비빔장을 만듭니다. 취향에 따라 양념 비율을 조절할 수 있습니다.
# 5. **비빔밥 완성:** 그릇에 밥을 담고, 준비한 고기, 야채, 계란반개, 김가루, 깨, 참기름을 올립니다. 비빔장을 따로 담아 개인 취향에 따라 섞어 먹습니다.
#
# **팁**
#
# * 다양한 야채를 활용하여 비빔밥의 맛과 영양을 더욱 풍부하게 만들 수 있습니다. (예: 오이고추, 버섯, 콩나물 대신)
# * 고기 대신 두부, 버섯 등 채식주의자를 위한 재료도 사용 가능합니다.
# * 비빔밥에 고추장 대신 간장을 사용하면 더욱 전통적인 맛을 즐길 수 있습니다.
#
# 맛있게 드세요! 🥗✨
