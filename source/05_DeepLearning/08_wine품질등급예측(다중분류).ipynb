# %%
from IPython.display import display, HTML
display(HTML("""
<style>
div.container{width:95% !important;}
div.cell.code_cell.rendered{width:95%;}
div.input_prompt{padding:0px;}
div.CodeMirror {font-family:Consolas; font-size:22pt;}
.inner_cell{font-size:22pt;}
div.text_cell_render pre code {font-size:22pt; line-height:30px;}
div.output {font-size:20pt; font-weight:bold;}
div.input {font-family:Consolas; font-size:22pt;}
div.prompt {min-width:70px;}
div#toc-wrapper{padding-top:120px;}
div.text_cell_render ul li{font-size:20pt;padding:5px;}
table.dataframe{font-size:22px;}
</style>
"""))
# Out:
# <style>
# div.container{width:95% !important;}
# div.cell.code_cell.rendered{width:95%;}
# div.input_prompt{padding:0px;}
# div.CodeMirror {font-family:Consolas; font-size:22pt;}
# .inner_cell{font-size:22pt;}
# div.text_cell_render pre code {font-size:22pt; line-height:30px;}
# div.output {font-size:20pt; font-weight:bold;}
# div.input {font-family:Consolas; font-size:22pt;}
# div.prompt {min-width:70px;}
# div#toc-wrapper{padding-top:120px;}
# div.text_cell_render ul li{font-size:20pt;padding:5px;}
# table.dataframe{font-size:22px;}
# </style>

# %%
# GPU 활성화 끄기
import os
os.environ['CUDA_VISIBLE_DEVICES'] = "-1"
# GPU 사용 여부 확인
import tensorflow as tf
print(tf.__version__)
tf.config.list_physical_devices('GPU')
# Out:
# 2.10.0
# []

# %% [markdown]
# # red wine 품질 등급 예측
# ```
# 1. 데이터 셋 확보 & 전처리
#     결측치 처리 -> 독립(입력)변수와 종속(타겟)변수를 분리 -> 독립변수의 스케일조정(StandardScaler)
#     -> 종속변수의 균형을 확인
#     -> 종속변수 원핫인코딩(pd.get_dummies) -> 훈련셋과 테스트셋분리(train_test_split)
# 2. 모델구성
# 3. 모델학습과정 설정(다중분류)
# 4. 모델학습(callbacks, compute_class_weight를 이용)
# 5. 모델 평가(시각화, 평가, 교차표 - 테스트셋)
# 6. 모델 저장/예측
# ```
#
# ## 1. 데이터셋확보 및 전처리

# %%
import numpy as np
import pandas as pd
from sklearn.preprocessing import StandardScaler, MinMaxScaler
from sklearn.model_selection import train_test_split
from tensorflow.keras.models import Sequential, save_model, load_model
from tensorflow.keras.layers import Input, Dense, LeakyReLU, Dropout, BatchNormalization
from tensorflow.keras.initializers import HeNormal
from tensorflow.keras.regularizers import l2
from tensorflow.keras import metrics # metrics.Recall, metrics.Precision
from sklearn.utils.class_weight import compute_class_weight
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint, Callback, ReduceLROnPlateau
from matplotlib import pyplot as plt

# %%
redwine = pd.read_csv('data/winequality-red.csv', sep=';')
redwine.info() # 결측치 없음
# redwine = np.loadtxt('data/winequality-red.csv', delimiter=';', skiprows=1) 넘파이배열로
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1599 entries, 0 to 1598
# Data columns (total 12 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   fixed acidity         1599 non-null   float64
#  1   volatile acidity      1599 non-null   float64
#  2   citric acid           1599 non-null   float64
#  3   residual sugar        1599 non-null   float64
#  4   chlorides             1599 non-null   float64
#  5   free sulfur dioxide   1599 non-null   float64
#  6   total sulfur dioxide  1599 non-null   float64
#  7   density               1599 non-null   float64
#  8   pH                    1599 non-null   float64
#  9   sulphates             1599 non-null   float64
#  10  alcohol               1599 non-null   float64
#  11  quality               1599 non-null   int64
# dtypes: float64(11), int64(1)
# memory usage: 150.0 KB

# %%
# 독립(입력)변수와 종속(타겟)변수를 분리
X_redwine = redwine.iloc[:, :-1].to_numpy() #.values과 유사. numpy로 변경
y_redwine = redwine.iloc[:, -1]#.values
X_redwine.shape, y_redwine.shape
# Out:
# ((1599, 11), (1599,))

# %%
# 독립변수의 스케일조정
scaler = StandardScaler()
# scaler.fit(X_redwine)
# scaled_X_redwine = scaler.transform(X_redwine)
scaled_X_redwine = scaler.fit_transform(X_redwine)

# %%
# 종속변수의 원핫인코딩
Y_redwine = pd.get_dummies(y_redwine).values
np.c_[y_redwine[2:4], Y_redwine[2:4]] # 원데이터와 원핫인코딩
# Out:
# array([[5, 0, 0, 1, 0, 0, 0],
#        [6, 0, 0, 0, 1, 0, 0]], dtype=int64)

# %%
# 종속변수의 균형을 확인
y_redwine.value_counts(normalize=True)
# Out:
# 5    0.425891
# 6    0.398999
# 7    0.124453
# 4    0.033146
# 8    0.011257
# 3    0.006254
# Name: quality, dtype: float64

# %%
# 독립변수와 타겟변수
scaled_X_redwine.shape, Y_redwine.shape
# Out:
# ((1599, 11), (1599, 6))

# %%
# 훈련셋과 테스트셋 분리(층화추출) = 7 : 3
X_train, X_test, Y_train, Y_test = train_test_split(scaled_X_redwine,
                                                   Y_redwine,
                                                   test_size=0.3,
                                                   #train_size=0.7,
                                                   stratify=Y_redwine, # 층화추출
                                                   random_state=12) # seed값
X_train.shape, X_test.shape, Y_train.shape, Y_test.shape
# Out:
# ((1119, 11), (480, 11), (1119, 6), (480, 6))

# %% [markdown]
# # 2. 모델구성
# - 입력 11 -> 64 -> 50 -> 30 -> 출력 6
# - He초기화 : 층이 깊을 때 활성화함수를 relu사용시

# %%
model = Sequential(name='sequential')
model.add(Input(11))
model.add(Dense(units=64, activation='relu', kernel_initializer=HeNormal(seed=42)))
model.add(Dense(units=50, activation='relu', kernel_initializer='he_normal'))
model.add(Dropout(0.1))
model.add(Dense(units=30, activation='relu', kernel_initializer='he_normal'))
model.add(Dense(units=6, activation='softmax'))
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_12 (Dense)            (None, 64)                768
#
#  dense_13 (Dense)            (None, 50)                3250
#
#  dropout_2 (Dropout)         (None, 50)                0
#
#  dense_14 (Dense)            (None, 30)                1530
#
#  dense_15 (Dense)            (None, 6)                 186
#
# =================================================================
# Total params: 5,734
# Trainable params: 5,734
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# # 3. 학습과정 설정

# %%
model.compile(loss='categorical_crossentropy', # sparse_categorical_crossentropy
             optimizer='adam',
             metrics=['accuracy', 
                      metrics.Recall(name='recall'), 
                      metrics.Precision(name='precision')])

# %% [markdown]
# # 4. 학습시키기
# - callbacks 이용

# %%
# %%time
earlyStopping = EarlyStopping(monitor='val_loss', patience=50)
hist = model.fit(X_train, Y_train,
                validation_split=0.2, # 학습셋의 20%를 검증셋으로
                # class_weight=class_weight_dict,
                callbacks=[earlyStopping],
                epochs=200, 
                verbose=2)
# Out:
# Epoch 1/200
# 28/28 - 1s - loss: 1.7505 - accuracy: 0.3687 - recall: 0.1263 - precision: 0.3324 - val_loss: 1.4126 - val_accuracy: 0.4554 - val_recall: 0.2277 - val_precision: 0.5484 - 690ms/epoch - 25ms/step
# Epoch 2/200
# 28/28 - 0s - loss: 1.2150 - accuracy: 0.5006 - recall: 0.2961 - precision: 0.5532 - val_loss: 1.2443 - val_accuracy: 0.5402 - val_recall: 0.3304 - val_precision: 0.5873 - 47ms/epoch - 2ms/step
# Epoch 3/200
# 28/28 - 0s - loss: 1.1181 - accuracy: 0.5419 - recall: 0.3609 - precision: 0.5916 - val_loss: 1.1426 - val_accuracy: 0.5580 - val_recall: 0.3705 - val_precision: 0.6194 - 52ms/epoch - 2ms/step
# Epoch 4/200
# 28/28 - 0s - loss: 1.0418 - accuracy: 0.5676 - recall: 0.4112 - precision: 0.6185 - val_loss: 1.1138 - val_accuracy: 0.5580 - val_recall: 0.3705 - val_precision: 0.5929 - 53ms/epoch - 2ms/step
# Epoch 5/200
# 28/28 - 0s - loss: 1.0048 - accuracy: 0.5978 - recall: 0.4134 - precision: 0.6503 - val_loss: 1.0771 - val_accuracy: 0.5670 - val_recall: 0.3884 - val_precision: 0.6084 - 50ms/epoch - 2ms/step
# Epoch 6/200
# 28/28 - 0s - loss: 0.9920 - accuracy: 0.6022 - recall: 0.4559 - precision: 0.6355 - val_loss: 1.0660 - val_accuracy: 0.5670 - val_recall: 0.4464 - val_precision: 0.6410 - 53ms/epoch - 2ms/step
# Epoch 7/200
# 28/28 - 0s - loss: 0.9438 - accuracy: 0.6045 - recall: 0.4626 - precision: 0.6469 - val_loss: 1.0589 - val_accuracy: 0.5670 - val_recall: 0.4241 - val_precision: 0.5975 - 52ms/epoch - 2ms/step
# Epoch 8/200
# 28/28 - 0s - loss: 0.9295 - accuracy: 0.6056 - recall: 0.4939 - precision: 0.6667 - val_loss: 1.0505 - val_accuracy: 0.5804 - val_recall: 0.4598 - val_precision: 0.6095 - 51ms/epoch - 2ms/step
# Epoch 9/200
# 28/28 - 0s - loss: 0.9228 - accuracy: 0.6056 - recall: 0.4827 - precision: 0.6467 - val_loss: 1.0439 - val_accuracy: 0.5848 - val_recall: 0.4598 - val_precision: 0.6023 - 51ms/epoch - 2ms/step
# Epoch 10/200
# 28/28 - 0s - loss: 0.9092 - accuracy: 0.6201 - recall: 0.5006 - precision: 0.6598 - val_loss: 1.0133 - val_accuracy: 0.5893 - val_recall: 0.4509 - val_precision: 0.6352 - 50ms/epoch - 2ms/step
# Epoch 11/200
# 28/28 - 0s - loss: 0.8825 - accuracy: 0.6268 - recall: 0.4916 - precision: 0.6728 - val_loss: 1.0328 - val_accuracy: 0.5938 - val_recall: 0.4420 - val_precision: 0.5928 - 54ms/epoch - 2ms/step
# Epoch 12/200
# 28/28 - 0s - loss: 0.8812 - accuracy: 0.6190 - recall: 0.5263 - precision: 0.6643 - val_loss: 1.0348 - val_accuracy: 0.5804 - val_recall: 0.4643 - val_precision: 0.6190 - 51ms/epoch - 2ms/step
# Epoch 13/200
# 28/28 - 0s - loss: 0.8522 - accuracy: 0.6547 - recall: 0.5408 - precision: 0.7035 - val_loss: 1.0141 - val_accuracy: 0.5670 - val_recall: 0.4554 - val_precision: 0.6296 - 54ms/epoch - 2ms/step
# Epoch 14/200
# 28/28 - 0s - loss: 0.8546 - accuracy: 0.6514 - recall: 0.5363 - precision: 0.6809 - val_loss: 1.0211 - val_accuracy: 0.5804 - val_recall: 0.4821 - val_precision: 0.6171 - 50ms/epoch - 2ms/step
# Epoch 15/200
# 28/28 - 0s - loss: 0.8396 - accuracy: 0.6581 - recall: 0.5475 - precision: 0.7030 - val_loss: 1.0150 - val_accuracy: 0.5714 - val_recall: 0.4777 - val_precision: 0.6114 - 52ms/epoch - 2ms/step
# Epoch 16/200
# 28/28 - 0s - loss: 0.8212 - accuracy: 0.6525 - recall: 0.5631 - precision: 0.6933 - val_loss: 1.0129 - val_accuracy: 0.5804 - val_recall: 0.4821 - val_precision: 0.6136 - 53ms/epoch - 2ms/step
# Epoch 17/200
# 28/28 - 0s - loss: 0.8021 - accuracy: 0.6648 - recall: 0.5933 - precision: 0.7080 - val_loss: 1.0164 - val_accuracy: 0.5893 - val_recall: 0.4777 - val_precision: 0.6045 - 50ms/epoch - 2ms/step
# Epoch 18/200
# 28/28 - 0s - loss: 0.8000 - accuracy: 0.6570 - recall: 0.5620 - precision: 0.7105 - val_loss: 1.0318 - val_accuracy: 0.5759 - val_recall: 0.4821 - val_precision: 0.5902 - 54ms/epoch - 2ms/step
# Epoch 19/200
# 28/28 - 0s - loss: 0.7935 - accuracy: 0.6626 - recall: 0.5877 - precision: 0.6985 - val_loss: 1.0146 - val_accuracy: 0.5714 - val_recall: 0.5000 - val_precision: 0.6120 - 49ms/epoch - 2ms/step
# Epoch 20/200
# 28/28 - 0s - loss: 0.7765 - accuracy: 0.6637 - recall: 0.5933 - precision: 0.7080 - val_loss: 1.0197 - val_accuracy: 0.5580 - val_recall: 0.4777 - val_precision: 0.6080 - 51ms/epoch - 2ms/step
# Epoch 21/200
# 28/28 - 0s - loss: 0.7701 - accuracy: 0.6939 - recall: 0.6011 - precision: 0.7231 - val_loss: 1.0356 - val_accuracy: 0.5580 - val_recall: 0.4955 - val_precision: 0.6099 - 51ms/epoch - 2ms/step
# Epoch 22/200
# 28/28 - 0s - loss: 0.7671 - accuracy: 0.6749 - recall: 0.5978 - precision: 0.7105 - val_loss: 1.0279 - val_accuracy: 0.5848 - val_recall: 0.4911 - val_precision: 0.5978 - 46ms/epoch - 2ms/step
# Epoch 23/200
# 28/28 - 0s - loss: 0.7524 - accuracy: 0.6715 - recall: 0.5899 - precision: 0.7253 - val_loss: 1.0125 - val_accuracy: 0.5759 - val_recall: 0.4955 - val_precision: 0.6271 - 45ms/epoch - 2ms/step
# Epoch 24/200
# 28/28 - 0s - loss: 0.7391 - accuracy: 0.6816 - recall: 0.6156 - precision: 0.7221 - val_loss: 1.0330 - val_accuracy: 0.5893 - val_recall: 0.4955 - val_precision: 0.6236 - 50ms/epoch - 2ms/step
# Epoch 25/200
# 28/28 - 0s - loss: 0.7307 - accuracy: 0.6961 - recall: 0.6291 - precision: 0.7398 - val_loss: 1.0413 - val_accuracy: 0.5714 - val_recall: 0.4866 - val_precision: 0.5956 - 48ms/epoch - 2ms/step
# Epoch 26/200
# 28/28 - 0s - loss: 0.7245 - accuracy: 0.7173 - recall: 0.6480 - precision: 0.7465 - val_loss: 1.0276 - val_accuracy: 0.5670 - val_recall: 0.5045 - val_precision: 0.5885 - 50ms/epoch - 2ms/step
# Epoch 27/200
# 28/28 - 0s - loss: 0.7157 - accuracy: 0.7173 - recall: 0.6369 - precision: 0.7550 - val_loss: 1.0339 - val_accuracy: 0.5580 - val_recall: 0.5223 - val_precision: 0.6126 - 46ms/epoch - 2ms/step
# Epoch 28/200
# 28/28 - 0s - loss: 0.7021 - accuracy: 0.7050 - recall: 0.6391 - precision: 0.7409 - val_loss: 1.0135 - val_accuracy: 0.6071 - val_recall: 0.5312 - val_precision: 0.6364 - 49ms/epoch - 2ms/step
# Epoch 29/200
# 28/28 - 0s - loss: 0.6922 - accuracy: 0.7039 - recall: 0.6257 - precision: 0.7427 - val_loss: 1.0470 - val_accuracy: 0.5938 - val_recall: 0.5089 - val_precision: 0.6196 - 46ms/epoch - 2ms/step
# Epoch 30/200
# 28/28 - 0s - loss: 0.6948 - accuracy: 0.7061 - recall: 0.6480 - precision: 0.7407 - val_loss: 1.0327 - val_accuracy: 0.5982 - val_recall: 0.5134 - val_precision: 0.6117 - 49ms/epoch - 2ms/step
# Epoch 31/200
# 28/28 - 0s - loss: 0.6706 - accuracy: 0.7307 - recall: 0.6592 - precision: 0.7652 - val_loss: 1.0500 - val_accuracy: 0.5893 - val_recall: 0.5134 - val_precision: 0.6021 - 47ms/epoch - 2ms/step
# Epoch 32/200
# 28/28 - 0s - loss: 0.6705 - accuracy: 0.7251 - recall: 0.6782 - precision: 0.7674 - val_loss: 1.0324 - val_accuracy: 0.6116 - val_recall: 0.5268 - val_precision: 0.6344 - 48ms/epoch - 2ms/step
# Epoch 33/200
# 28/28 - 0s - loss: 0.6676 - accuracy: 0.7307 - recall: 0.6626 - precision: 0.7525 - val_loss: 1.0850 - val_accuracy: 0.5491 - val_recall: 0.5223 - val_precision: 0.5969 - 53ms/epoch - 2ms/step
# Epoch 34/200
# 28/28 - 0s - loss: 0.6601 - accuracy: 0.7341 - recall: 0.6749 - precision: 0.7724 - val_loss: 1.0289 - val_accuracy: 0.6116 - val_recall: 0.5446 - val_precision: 0.6455 - 49ms/epoch - 2ms/step
# Epoch 35/200
# 28/28 - 0s - loss: 0.6488 - accuracy: 0.7296 - recall: 0.6760 - precision: 0.7697 - val_loss: 1.0225 - val_accuracy: 0.6250 - val_recall: 0.5491 - val_precision: 0.6508 - 46ms/epoch - 2ms/step
# Epoch 36/200
# 28/28 - 0s - loss: 0.6364 - accuracy: 0.7497 - recall: 0.6760 - precision: 0.7668 - val_loss: 1.0479 - val_accuracy: 0.5848 - val_recall: 0.5312 - val_precision: 0.6296 - 49ms/epoch - 2ms/step
# Epoch 37/200
# 28/28 - 0s - loss: 0.6380 - accuracy: 0.7397 - recall: 0.6804 - precision: 0.7768 - val_loss: 1.0484 - val_accuracy: 0.5804 - val_recall: 0.5312 - val_precision: 0.6134 - 47ms/epoch - 2ms/step
# Epoch 38/200
# 28/28 - 0s - loss: 0.6313 - accuracy: 0.7363 - recall: 0.6827 - precision: 0.7695 - val_loss: 1.0460 - val_accuracy: 0.6116 - val_recall: 0.5491 - val_precision: 0.6276 - 54ms/epoch - 2ms/step
# Epoch 39/200
# 28/28 - 0s - loss: 0.6302 - accuracy: 0.7430 - recall: 0.6793 - precision: 0.7745 - val_loss: 1.0580 - val_accuracy: 0.5938 - val_recall: 0.5223 - val_precision: 0.6126 - 52ms/epoch - 2ms/step
# Epoch 40/200
# 28/28 - 0s - loss: 0.6105 - accuracy: 0.7553 - recall: 0.6983 - precision: 0.7881 - val_loss: 1.0777 - val_accuracy: 0.5848 - val_recall: 0.5357 - val_precision: 0.6000 - 50ms/epoch - 2ms/step
# Epoch 41/200
# 28/28 - 0s - loss: 0.5950 - accuracy: 0.7553 - recall: 0.7028 - precision: 0.7804 - val_loss: 1.0683 - val_accuracy: 0.5938 - val_recall: 0.5446 - val_precision: 0.6070 - 48ms/epoch - 2ms/step
# Epoch 42/200
# 28/28 - 0s - loss: 0.6087 - accuracy: 0.7587 - recall: 0.7006 - precision: 0.7877 - val_loss: 1.0844 - val_accuracy: 0.5893 - val_recall: 0.5491 - val_precision: 0.6181 - 50ms/epoch - 2ms/step
# Epoch 43/200
# 28/28 - 0s - loss: 0.5961 - accuracy: 0.7318 - recall: 0.6927 - precision: 0.7664 - val_loss: 1.0595 - val_accuracy: 0.6027 - val_recall: 0.5536 - val_precision: 0.6327 - 49ms/epoch - 2ms/step
# Epoch 44/200
# 28/28 - 0s - loss: 0.6006 - accuracy: 0.7609 - recall: 0.7061 - precision: 0.7920 - val_loss: 1.0835 - val_accuracy: 0.5938 - val_recall: 0.5402 - val_precision: 0.6142 - 52ms/epoch - 2ms/step
# Epoch 45/200
# 28/28 - 0s - loss: 0.5717 - accuracy: 0.7609 - recall: 0.7061 - precision: 0.7890 - val_loss: 1.0924 - val_accuracy: 0.5848 - val_recall: 0.5491 - val_precision: 0.6181 - 48ms/epoch - 2ms/step
# Epoch 46/200
# 28/28 - 0s - loss: 0.5543 - accuracy: 0.7810 - recall: 0.7318 - precision: 0.8057 - val_loss: 1.0713 - val_accuracy: 0.6027 - val_recall: 0.5446 - val_precision: 0.6224 - 54ms/epoch - 2ms/step
# Epoch 47/200
# 28/28 - 0s - loss: 0.5677 - accuracy: 0.7676 - recall: 0.7218 - precision: 0.7888 - val_loss: 1.0829 - val_accuracy: 0.5982 - val_recall: 0.5536 - val_precision: 0.6200 - 54ms/epoch - 2ms/step
# Epoch 48/200
# 28/28 - 0s - loss: 0.5482 - accuracy: 0.7777 - recall: 0.7385 - precision: 0.8160 - val_loss: 1.0959 - val_accuracy: 0.5982 - val_recall: 0.5446 - val_precision: 0.6256 - 50ms/epoch - 2ms/step
# Epoch 49/200
# 28/28 - 0s - loss: 0.5592 - accuracy: 0.7654 - recall: 0.7196 - precision: 0.7941 - val_loss: 1.1024 - val_accuracy: 0.5982 - val_recall: 0.5536 - val_precision: 0.6169 - 55ms/epoch - 2ms/step
# Epoch 50/200
# 28/28 - 0s - loss: 0.5427 - accuracy: 0.7877 - recall: 0.7374 - precision: 0.8098 - val_loss: 1.1007 - val_accuracy: 0.6027 - val_recall: 0.5580 - val_precision: 0.6250 - 50ms/epoch - 2ms/step
# Epoch 51/200
# 28/28 - 0s - loss: 0.5300 - accuracy: 0.7866 - recall: 0.7397 - precision: 0.8234 - val_loss: 1.0832 - val_accuracy: 0.6027 - val_recall: 0.5491 - val_precision: 0.6244 - 53ms/epoch - 2ms/step
# Epoch 52/200
# 28/28 - 0s - loss: 0.5199 - accuracy: 0.7955 - recall: 0.7486 - precision: 0.8221 - val_loss: 1.0945 - val_accuracy: 0.5848 - val_recall: 0.5491 - val_precision: 0.6089 - 51ms/epoch - 2ms/step
# Epoch 53/200
# 28/28 - 0s - loss: 0.5332 - accuracy: 0.7855 - recall: 0.7475 - precision: 0.8080 - val_loss: 1.1084 - val_accuracy: 0.5982 - val_recall: 0.5491 - val_precision: 0.6212 - 48ms/epoch - 2ms/step
# Epoch 54/200
# 28/28 - 0s - loss: 0.4996 - accuracy: 0.8011 - recall: 0.7598 - precision: 0.8293 - val_loss: 1.1114 - val_accuracy: 0.5893 - val_recall: 0.5536 - val_precision: 0.6139 - 49ms/epoch - 2ms/step
# Epoch 55/200
# 28/28 - 0s - loss: 0.5072 - accuracy: 0.8022 - recall: 0.7620 - precision: 0.8358 - val_loss: 1.1172 - val_accuracy: 0.5938 - val_recall: 0.5580 - val_precision: 0.6281 - 48ms/epoch - 2ms/step
# Epoch 56/200
# 28/28 - 0s - loss: 0.5039 - accuracy: 0.7933 - recall: 0.7620 - precision: 0.8277 - val_loss: 1.1629 - val_accuracy: 0.5580 - val_recall: 0.5312 - val_precision: 0.5950 - 51ms/epoch - 2ms/step
# Epoch 57/200
# 28/28 - 0s - loss: 0.5083 - accuracy: 0.7933 - recall: 0.7542 - precision: 0.8272 - val_loss: 1.0841 - val_accuracy: 0.6295 - val_recall: 0.5714 - val_precision: 0.6400 - 48ms/epoch - 2ms/step
# Epoch 58/200
# 28/28 - 0s - loss: 0.5002 - accuracy: 0.7844 - recall: 0.7520 - precision: 0.8128 - val_loss: 1.1138 - val_accuracy: 0.6071 - val_recall: 0.5625 - val_precision: 0.6269 - 50ms/epoch - 2ms/step
# Epoch 59/200
# 28/28 - 0s - loss: 0.4891 - accuracy: 0.8022 - recall: 0.7654 - precision: 0.8384 - val_loss: 1.1062 - val_accuracy: 0.5938 - val_recall: 0.5446 - val_precision: 0.6131 - 49ms/epoch - 2ms/step
# Epoch 60/200
# 28/28 - 0s - loss: 0.4871 - accuracy: 0.8168 - recall: 0.7709 - precision: 0.8415 - val_loss: 1.1145 - val_accuracy: 0.5982 - val_recall: 0.5625 - val_precision: 0.6029 - 52ms/epoch - 2ms/step
# Epoch 61/200
# 28/28 - 0s - loss: 0.4704 - accuracy: 0.8212 - recall: 0.7899 - precision: 0.8347 - val_loss: 1.1368 - val_accuracy: 0.5938 - val_recall: 0.5580 - val_precision: 0.6068 - 48ms/epoch - 2ms/step
# Epoch 62/200
# 28/28 - 0s - loss: 0.4693 - accuracy: 0.7989 - recall: 0.7709 - precision: 0.8234 - val_loss: 1.1054 - val_accuracy: 0.5938 - val_recall: 0.5714 - val_precision: 0.6275 - 50ms/epoch - 2ms/step
# Epoch 63/200
# 28/28 - 0s - loss: 0.4633 - accuracy: 0.8156 - recall: 0.7799 - precision: 0.8400 - val_loss: 1.1471 - val_accuracy: 0.5938 - val_recall: 0.5536 - val_precision: 0.6078 - 48ms/epoch - 2ms/step
# Epoch 64/200
# 28/28 - 0s - loss: 0.4510 - accuracy: 0.8235 - recall: 0.7978 - precision: 0.8440 - val_loss: 1.1324 - val_accuracy: 0.6116 - val_recall: 0.5848 - val_precision: 0.6359 - 50ms/epoch - 2ms/step
# Epoch 65/200
# 28/28 - 0s - loss: 0.4550 - accuracy: 0.8179 - recall: 0.7832 - precision: 0.8365 - val_loss: 1.1480 - val_accuracy: 0.5938 - val_recall: 0.5536 - val_precision: 0.6108 - 50ms/epoch - 2ms/step
# Epoch 66/200
# 28/28 - 0s - loss: 0.4555 - accuracy: 0.8223 - recall: 0.7933 - precision: 0.8442 - val_loss: 1.1459 - val_accuracy: 0.6027 - val_recall: 0.5625 - val_precision: 0.6146 - 50ms/epoch - 2ms/step
# Epoch 67/200
# 28/28 - 0s - loss: 0.4385 - accuracy: 0.8257 - recall: 0.7989 - precision: 0.8542 - val_loss: 1.1518 - val_accuracy: 0.6339 - val_recall: 0.5893 - val_precision: 0.6377 - 47ms/epoch - 2ms/step
# Epoch 68/200
# 28/28 - 0s - loss: 0.4246 - accuracy: 0.8335 - recall: 0.8078 - precision: 0.8617 - val_loss: 1.1457 - val_accuracy: 0.6250 - val_recall: 0.5893 - val_precision: 0.6408 - 51ms/epoch - 2ms/step
# Epoch 69/200
# 28/28 - 0s - loss: 0.4204 - accuracy: 0.8436 - recall: 0.8145 - precision: 0.8648 - val_loss: 1.1563 - val_accuracy: 0.6116 - val_recall: 0.5938 - val_precision: 0.6425 - 47ms/epoch - 2ms/step
# Epoch 70/200
# 28/28 - 0s - loss: 0.4172 - accuracy: 0.8324 - recall: 0.8034 - precision: 0.8529 - val_loss: 1.1890 - val_accuracy: 0.6161 - val_recall: 0.5804 - val_precision: 0.6280 - 50ms/epoch - 2ms/step
# Epoch 71/200
# 28/28 - 0s - loss: 0.4285 - accuracy: 0.8346 - recall: 0.8056 - precision: 0.8543 - val_loss: 1.2118 - val_accuracy: 0.5938 - val_recall: 0.5625 - val_precision: 0.6117 - 49ms/epoch - 2ms/step
# Epoch 72/200
# 28/28 - 0s - loss: 0.4188 - accuracy: 0.8436 - recall: 0.8201 - precision: 0.8635 - val_loss: 1.2039 - val_accuracy: 0.6071 - val_recall: 0.5848 - val_precision: 0.6238 - 50ms/epoch - 2ms/step
# Epoch 73/200
# 28/28 - 0s - loss: 0.4059 - accuracy: 0.8480 - recall: 0.8257 - precision: 0.8674 - val_loss: 1.2141 - val_accuracy: 0.6116 - val_recall: 0.5804 - val_precision: 0.6280 - 48ms/epoch - 2ms/step
# CPU times: total: 6.5 s
# Wall time: 4.51 s

# %% [markdown]
# # 5. 모델평가
# - 시각화, 평가, 교차표

# %%
hist.history.keys()
# Out:
# dict_keys(['loss', 'accuracy', 'recall', 'precision', 'val_loss', 'val_accuracy', 'val_recall', 'val_precision'])

# %%
# 학습과정 살펴보기(시각화)
fig, loss_ax = plt.subplots(figsize=(15,6))
loss_ax.plot(hist.history['loss'], 'y', label='train_loss')
loss_ax.plot(hist.history['val_loss'], 'r', label='val_loss')
acc_ax = loss_ax.twinx()
acc_ax.plot(hist.history['accuracy'], 'g', label='train_accuracy')
acc_ax.plot(hist.history['val_accuracy'], 'b', label='val_accuracy')
acc_ax.plot(hist.history['val_recall'], 'k', label='val_accuracy')
acc_ax.plot(hist.history['val_precision'], 'k', label='val_accuracy')

acc_ax.set_ylabel('accuracy')
loss_ax.set_xlabel('epoch')
loss_ax.set_ylabel('loss')
loss_ax.legend(bbox_to_anchor=(0.97,0.75))
acc_ax.legend(loc='center right')
plt.show()

# %%
# 평가
loss, acc, recall, precision = model.evaluate(X_test, Y_test, verbose=0)
print('정확도 :', acc)
print('재현율 :', recall)
print('정밀도 :', precision)
# Out:
# 정확도 : 0.65625
# 재현율 : 0.6208333373069763
# 정밀도 : 0.6592920422554016

# %%
# 교차표를 위한 y_hat
y_hat = model.predict(X_test).argmax(axis=1) + 3 # 예측값
y = Y_test.argmax(axis=1) + 3 # 실제값
pd.crosstab(y, y_hat, rownames=['실제'], colnames=['예측'])
# Out:
# 15/15 [==============================] - 0s 733us/step
# 예측  4    5    6   7
# 실제
# 3   0    2    1   0
# 4   0    8    7   1
# 5   2  149   50   3
# 6   0   43  134  15
# 7   0    2   26  32
# 8   0    0    2   3

# %% [markdown]
# # 6. 모델 사용

# %%
X_redwine[0]
# Out:
# array([ 7.4   ,  0.7   ,  0.    ,  1.9   ,  0.076 , 11.    , 34.    ,
#         0.9978,  3.51  ,  0.56  ,  9.4   ])

# %%
data = [[ 7.4,0.7, 0.,  1.9,  0.076, 11., 34. , 0.9978,  3.51  ,  0.56  ,  9.4   ]]
input_data = scaler.transform(data)
model.predict(input_data).argmax(axis=1)+3
# Out:
# 1/1 [==============================] - 0s 17ms/step
# array([5], dtype=int64)
